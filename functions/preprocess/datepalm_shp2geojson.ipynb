# %%
import geopandas as gpd
import numpy as np, pandas as pd

# %%
gpd = gpd.read_file('/datawaha/esom/DatePalmCounting/Geoportal/Datepalm/app_server/datepalms/Qassim_othertree_fields_polygons.shp')
# Out:
# KeyboardInterrupt
